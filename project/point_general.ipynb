# %%
# Given the values of a single peakon on a coarse grid, this DNN predicts the value of the peakon at a particular location.
# Essentially, given the values shown by the @ and G symbols, and a location within the ... region, it will output its
# prediction for the value at that location.
#
#
# @   @   @   @   @   @
#
#
#
# @   @   @   @   @   @
#
#       .........
#       .       .
# @   @ . @   @ . @   @
#       .       .
#       .       .
#       .       .
# @   @ . G   @ . @   @
#       .       .
#       .........
#
# @   @   @   @   @   @
#
#
#
# @   @   @   @   @   @

# %%
import tensorflow as tf

from base import fenics as fc
from base import ml

# %%
# Set to False to use existing weights for the neural network.
# Set to True to continue training the weights from where we left off last time.
TRAIN = True

# %%
### DNN hyperparameters
hidden_units = [100] * 7
logits = 1
processor = ml.ScaleCenterAtPoint()
activation=tf.nn.crelu

### Training hyperparameters #1
drop_rate = 0.0
drop_type = 'dropout'
gradient_clip = 1.0  # May be set to None to turn off gradient clipping

### Logging/saving hyperparameters
log_steps = 1000  # How many steps to print the current loss.
model_dir_base = './saved_models/point_general/'
uuid = None
model_dir = ml.model_dir_str(model_dir_base, hidden_units, logits,
                             processor=processor, activation=activation, 
                             uuid=uuid)

compile_kwargs = {'gradient_clip': gradient_clip,
                  'processor': processor,
                  'model_dir': model_dir}
dnn_factory = ml.DNNFactory(hidden_units, logits, drop_rate=drop_rate,
                            drop_type=drop_type, log_steps=log_steps, 
                            activation=activation, batch_norm=False,
                            compile_kwargs=compile_kwargs)

max_steps = 0
if TRAIN:
    # Start off without using FEniCS solutions because they're so much
    # slower to generate
    gen_one_data = fc.GenGeneralSolutionAtPoint(num_fenics=0)
    
    ### Training hyperparameters #2
    batch_size = 50
    max_steps += 5000
    learning_rate = 0.001
    with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
        dnn = dnn_factory(learning_rate=learning_rate)
        dnn.train(input_fn=train_input_fn, max_steps=max_steps)
    
    # Start using FEniCS solutions
    gen_one_data = fc.GenGeneralSolutionAtPoint()
    
    batch_size = 500
    max_steps += 3000
    learning_rate = 0.001
    with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
        dnn = dnn_factory(learning_rate=learning_rate)
        dnn.train(input_fn=train_input_fn, max_steps=max_steps)
        
    batch_size = 500
    max_steps += 2000
    learning_rate = 0.0001
    with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
        dnn = dnn_factory(learning_rate=learning_rate)
        dnn.train(input_fn=train_input_fn, max_steps=max_steps)
        
    batch_size = 500
    max_steps += 1000
    learning_rate = 0.00001
    with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
        dnn = dnn_factory(learning_rate=learning_rate)
        dnn.train(input_fn=train_input_fn, max_steps=max_steps)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a9bbf8828>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 1.6866355, step = 1
# INFO:tensorflow:global_step/sec: 55.2525
# INFO:tensorflow:loss = 0.18083143, step = 1001 (18.100 sec)
# INFO:tensorflow:global_step/sec: 56.4155
# INFO:tensorflow:loss = 0.34628326, step = 2001 (17.725 sec)
# INFO:tensorflow:global_step/sec: 56.1184
# INFO:tensorflow:loss = 0.05710473, step = 3001 (17.819 sec)
# INFO:tensorflow:global_step/sec: 56.4012
# INFO:tensorflow:loss = 0.044787634, step = 4001 (17.730 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.008018432.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad031ae48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.06804168, step = 5001
# INFO:tensorflow:global_step/sec: 7.06658
# INFO:tensorflow:loss = 0.015339837, step = 6001 (141.513 sec)
# INFO:tensorflow:global_step/sec: 7.09104
# INFO:tensorflow:loss = 0.014623969, step = 7001 (141.023 sec)
# INFO:tensorflow:global_step/sec: 6.95
# INFO:tensorflow:loss = 0.019631341, step = 8001 (143.885 sec)
# INFO:tensorflow:global_step/sec: 7.0492
# INFO:tensorflow:loss = 0.018502487, step = 9001 (141.859 sec)
# INFO:tensorflow:Saving checkpoints for 9225 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0068253204.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad057c080>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.011999025, step = 10001
# INFO:tensorflow:global_step/sec: 2.42845
# INFO:tensorflow:loss = 0.0065183975, step = 11001 (411.787 sec)
# INFO:tensorflow:Saving checkpoints for 11456 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.42051
# INFO:tensorflow:loss = 0.0055532195, step = 12001 (413.136 sec)
# INFO:tensorflow:Saving checkpoints for 12890 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/30x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007573485.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a982d3c18>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.7105287, step = 1
# INFO:tensorflow:global_step/sec: 55.0493
# INFO:tensorflow:loss = 0.18117206, step = 1001 (18.167 sec)
# INFO:tensorflow:global_step/sec: 55.4593
# INFO:tensorflow:loss = 0.03899694, step = 2001 (18.031 sec)
# INFO:tensorflow:global_step/sec: 55.7248
# INFO:tensorflow:loss = 0.059382714, step = 3001 (17.945 sec)
# INFO:tensorflow:global_step/sec: 55.9357
# INFO:tensorflow:loss = 0.028509144, step = 4001 (17.878 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.030799288.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad02bee48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.026766125, step = 5001
# INFO:tensorflow:global_step/sec: 6.90188
# INFO:tensorflow:loss = 0.017127663, step = 6001 (144.890 sec)
# INFO:tensorflow:global_step/sec: 6.71354
# INFO:tensorflow:loss = 0.010422093, step = 7001 (148.953 sec)
# INFO:tensorflow:global_step/sec: 6.72103
# INFO:tensorflow:loss = 0.014005339, step = 8001 (148.787 sec)
# INFO:tensorflow:global_step/sec: 6.73448
# INFO:tensorflow:loss = 0.011602101, step = 9001 (148.489 sec)
# INFO:tensorflow:Saving checkpoints for 9059 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.005130647.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a982d3048>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.004975583, step = 10001
# INFO:tensorflow:global_step/sec: 2.30435
# INFO:tensorflow:loss = 0.0035704821, step = 11001 (433.963 sec)
# INFO:tensorflow:Saving checkpoints for 11390 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.25324
# INFO:tensorflow:loss = 0.0043330803, step = 12001 (443.806 sec)
# INFO:tensorflow:Saving checkpoints for 12771 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/30x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0033661595.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad0ac1ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.6011234, step = 1
# INFO:tensorflow:global_step/sec: 52.9148
# INFO:tensorflow:loss = 0.17455049, step = 1001 (18.900 sec)
# INFO:tensorflow:global_step/sec: 53.2615
# INFO:tensorflow:loss = 0.040295094, step = 2001 (18.775 sec)
# INFO:tensorflow:global_step/sec: 52.9892
# INFO:tensorflow:loss = 0.046801735, step = 3001 (18.872 sec)
# INFO:tensorflow:global_step/sec: 53.4122
# INFO:tensorflow:loss = 0.025413848, step = 4001 (18.722 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.017018337.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a981fefd0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.05301783, step = 5001
# INFO:tensorflow:global_step/sec: 6.7065
# INFO:tensorflow:loss = 0.015016989, step = 6001 (149.111 sec)
# INFO:tensorflow:global_step/sec: 6.7178
# INFO:tensorflow:loss = 0.011925033, step = 7001 (148.859 sec)
# INFO:tensorflow:global_step/sec: 6.80888
# INFO:tensorflow:loss = 0.0066260495, step = 8001 (146.866 sec)
# INFO:tensorflow:global_step/sec: 6.83406
# INFO:tensorflow:loss = 0.0062516923, step = 9001 (146.326 sec)
# INFO:tensorflow:Saving checkpoints for 9060 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.014953314.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad0494e48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.011703161, step = 10001
# INFO:tensorflow:global_step/sec: 2.30407
# INFO:tensorflow:loss = 0.0037447482, step = 11001 (434.017 sec)
# INFO:tensorflow:Saving checkpoints for 11377 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.25827
# INFO:tensorflow:loss = 0.0034575958, step = 12001 (442.818 sec)
# INFO:tensorflow:Saving checkpoints for 12711 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/30x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0043265834.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ae312d4a8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.88636756, step = 1
# INFO:tensorflow:global_step/sec: 53.8028
# INFO:tensorflow:loss = 0.15576246, step = 1001 (18.588 sec)
# INFO:tensorflow:global_step/sec: 53.7298
# INFO:tensorflow:loss = 0.09457665, step = 2001 (18.612 sec)
# INFO:tensorflow:global_step/sec: 53.3477
# INFO:tensorflow:loss = 0.14450805, step = 3001 (18.745 sec)
# INFO:tensorflow:global_step/sec: 53.8951
# INFO:tensorflow:loss = 0.07825234, step = 4001 (18.554 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.018699775.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad011c160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.041537214, step = 5001
# INFO:tensorflow:global_step/sec: 6.93412
# INFO:tensorflow:loss = 0.016466439, step = 6001 (144.216 sec)
# INFO:tensorflow:global_step/sec: 6.15098
# INFO:tensorflow:loss = 0.024381446, step = 7001 (162.575 sec)
# INFO:tensorflow:global_step/sec: 6.89295
# INFO:tensorflow:loss = 0.020577459, step = 8001 (145.076 sec)
# INFO:tensorflow:global_step/sec: 6.8647
# INFO:tensorflow:loss = 0.014335669, step = 9001 (145.673 sec)
# INFO:tensorflow:Saving checkpoints for 9017 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.017978435.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a980acdd8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.013291679, step = 10001
# INFO:tensorflow:global_step/sec: 2.19945
# INFO:tensorflow:loss = 0.009770354, step = 11001 (454.661 sec)
# INFO:tensorflow:Saving checkpoints for 11330 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.27458
# INFO:tensorflow:loss = 0.008876436, step = 12001 (439.641 sec)
# INFO:tensorflow:Saving checkpoints for 12705 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/40x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0067457776.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad0929cc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.44372183, step = 1
# INFO:tensorflow:global_step/sec: 50.3727
# INFO:tensorflow:loss = 0.37278074, step = 1001 (19.854 sec)
# INFO:tensorflow:global_step/sec: 48.8385
# INFO:tensorflow:loss = 0.062654726, step = 2001 (20.475 sec)
# INFO:tensorflow:global_step/sec: 45.2448
# INFO:tensorflow:loss = 0.04193688, step = 3001 (22.102 sec)
# INFO:tensorflow:global_step/sec: 50.0308
# INFO:tensorflow:loss = 0.052915752, step = 4001 (19.988 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.008387101.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad020fb38>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.05530219, step = 5001
# INFO:tensorflow:global_step/sec: 6.68992
# INFO:tensorflow:loss = 0.011311645, step = 6001 (149.480 sec)
# INFO:tensorflow:global_step/sec: 6.83913
# INFO:tensorflow:loss = 0.009566346, step = 7001 (146.218 sec)
# INFO:tensorflow:global_step/sec: 6.83905
# INFO:tensorflow:loss = 0.009425012, step = 8001 (146.219 sec)
# INFO:tensorflow:global_step/sec: 6.80976
# INFO:tensorflow:loss = 0.012257783, step = 9001 (146.848 sec)
# INFO:tensorflow:Saving checkpoints for 9076 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0071452097.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a98052320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.015447507, step = 10001
# INFO:tensorflow:global_step/sec: 2.24504
# INFO:tensorflow:loss = 0.0049532754, step = 11001 (445.429 sec)
# INFO:tensorflow:Saving checkpoints for 11349 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.33488
# INFO:tensorflow:loss = 0.0026908768, step = 12001 (428.289 sec)
# INFO:tensorflow:Saving checkpoints for 12777 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/40x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0037046848.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a9822d5c0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.42696384, step = 1
# INFO:tensorflow:global_step/sec: 51.9883
# INFO:tensorflow:loss = 0.14861616, step = 1001 (19.237 sec)
# INFO:tensorflow:global_step/sec: 51.9107
# INFO:tensorflow:loss = 0.05109593, step = 2001 (19.264 sec)
# INFO:tensorflow:global_step/sec: 51.6385
# INFO:tensorflow:loss = 0.042497538, step = 3001 (19.366 sec)
# INFO:tensorflow:global_step/sec: 51.3004
# INFO:tensorflow:loss = 0.040478304, step = 4001 (19.493 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.009256306.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a9ab4b1d0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0405154, step = 5001
# INFO:tensorflow:global_step/sec: 6.59254
# INFO:tensorflow:loss = 0.031467147, step = 6001 (151.689 sec)
# INFO:tensorflow:global_step/sec: 6.64729
# INFO:tensorflow:loss = 0.017245602, step = 7001 (150.437 sec)
# INFO:tensorflow:global_step/sec: 6.44409
# INFO:tensorflow:loss = 0.024645297, step = 8001 (155.181 sec)
# INFO:tensorflow:Saving checkpoints for 8916 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.43392
# INFO:tensorflow:loss = 0.008607309, step = 9001 (155.426 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.017073452.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a9822d4a8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.005873151, step = 10001
# INFO:tensorflow:global_step/sec: 2.23809
# INFO:tensorflow:loss = 0.0051435395, step = 11001 (446.812 sec)
# INFO:tensorflow:Saving checkpoints for 11250 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.35029
# INFO:tensorflow:loss = 0.0071358336, step = 12001 (740.583 sec)
# INFO:tensorflow:Saving checkpoints for 12017 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 12735 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/40x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.003925639.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a687e54a8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 1.2018541, step = 1
# INFO:tensorflow:global_step/sec: 27.6797
# INFO:tensorflow:loss = 0.24159081, step = 1001 (36.130 sec)
# INFO:tensorflow:global_step/sec: 28.197
# INFO:tensorflow:loss = 0.06578461, step = 2001 (35.464 sec)
# INFO:tensorflow:global_step/sec: 28.0842
# INFO:tensorflow:loss = 0.038135875, step = 3001 (35.608 sec)
# INFO:tensorflow:global_step/sec: 28.2152
# INFO:tensorflow:loss = 0.052672625, step = 4001 (35.442 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007593613.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1aeb1c10b8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.040019877, step = 5001
# INFO:tensorflow:global_step/sec: 3.70652
# INFO:tensorflow:loss = 0.016854828, step = 6001 (269.797 sec)
# INFO:tensorflow:global_step/sec: 3.70694
# INFO:tensorflow:loss = 0.00835902, step = 7001 (269.765 sec)
# INFO:tensorflow:Saving checkpoints for 7223 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.69914
# INFO:tensorflow:loss = 0.053396557, step = 8001 (270.333 sec)
# INFO:tensorflow:global_step/sec: 3.70588
# INFO:tensorflow:loss = 0.022423644, step = 9001 (269.841 sec)
# INFO:tensorflow:Saving checkpoints for 9444 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0070053185.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad0376ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.009371886, step = 10001
# INFO:tensorflow:Saving checkpoints for 10760 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.26718
# INFO:tensorflow:loss = 0.005237604, step = 11001 (789.158 sec)
# INFO:tensorflow:Saving checkpoints for 11526 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.27197
# INFO:tensorflow:loss = 0.0045897756, step = 12001 (786.184 sec)
# INFO:tensorflow:Saving checkpoints for 12279 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/50x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.009856355.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a981fe940>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.4761219, step = 1
# INFO:tensorflow:global_step/sec: 26.8513
# INFO:tensorflow:loss = 0.10029102, step = 1001 (37.244 sec)
# INFO:tensorflow:global_step/sec: 26.7989
# INFO:tensorflow:loss = 0.03182044, step = 2001 (37.315 sec)
# INFO:tensorflow:global_step/sec: 26.9611
# INFO:tensorflow:loss = 0.1162425, step = 3001 (37.090 sec)
# INFO:tensorflow:global_step/sec: 26.4989
# INFO:tensorflow:loss = 0.074673034, step = 4001 (37.738 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.116779245.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a982156d8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.03227437, step = 5001
# INFO:tensorflow:global_step/sec: 3.5386
# INFO:tensorflow:loss = 0.020189906, step = 6001 (282.601 sec)
# INFO:tensorflow:global_step/sec: 3.52569
# INFO:tensorflow:loss = 0.015299487, step = 7001 (283.633 sec)
# INFO:tensorflow:Saving checkpoints for 7119 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.55313
# INFO:tensorflow:loss = 0.011998525, step = 8001 (281.440 sec)
# INFO:tensorflow:global_step/sec: 3.58648
# INFO:tensorflow:loss = 0.008696035, step = 9001 (278.825 sec)
# INFO:tensorflow:Saving checkpoints for 9265 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0040204492.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ad0b80550>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.013250004, step = 10001
# INFO:tensorflow:Saving checkpoints for 10735 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.23796
# INFO:tensorflow:loss = 0.0053104428, step = 11001 (807.783 sec)
# INFO:tensorflow:Saving checkpoints for 11535 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.30633
# INFO:tensorflow:loss = 0.0043221256, step = 12001 (765.506 sec)
# INFO:tensorflow:Saving checkpoints for 12285 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/50x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0048173247.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a686b59b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.56939137, step = 1
# INFO:tensorflow:global_step/sec: 26.2959
# INFO:tensorflow:loss = 0.63568866, step = 1001 (38.030 sec)
# INFO:tensorflow:global_step/sec: 26.3101
# INFO:tensorflow:loss = 0.067404285, step = 2001 (38.008 sec)
# INFO:tensorflow:global_step/sec: 26.8255
# INFO:tensorflow:loss = 0.042849764, step = 3001 (37.278 sec)
# INFO:tensorflow:global_step/sec: 26.5355
# INFO:tensorflow:loss = 0.030995293, step = 4001 (37.686 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0075896615.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a686af128>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.09138932, step = 5001
# INFO:tensorflow:global_step/sec: 3.38933
# INFO:tensorflow:loss = 0.011592371, step = 6001 (295.046 sec)
# INFO:tensorflow:global_step/sec: 3.46988
# INFO:tensorflow:loss = 0.012008132, step = 7001 (288.194 sec)
# INFO:tensorflow:Saving checkpoints for 7057 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.47242
# INFO:tensorflow:loss = 0.034243625, step = 8001 (288.014 sec)
# INFO:tensorflow:global_step/sec: 3.50724
# INFO:tensorflow:loss = 0.014030101, step = 9001 (285.094 sec)
# INFO:tensorflow:Saving checkpoints for 9154 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0059230146.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1a681f06d8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0067340336, step = 10001
# INFO:tensorflow:Saving checkpoints for 10703 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.17728
# INFO:tensorflow:loss = 0.005540323, step = 11001 (849.419 sec)
# INFO:tensorflow:Saving checkpoints for 11419 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.19814
# INFO:tensorflow:loss = 0.008138891, step = 12001 (834.625 sec)
# INFO:tensorflow:Saving checkpoints for 12138 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 12834 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_multi_peakon/50x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.014893973.
