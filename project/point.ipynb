# %%
# Given the values of a solution on a coarse grid, this DNN predicts the value of the solution at a particular location.
# Essentially, given the values shown by the @ symbol, and a location within the ... region, it will output its
# prediction for the value at that location.
#
#
# @   @   @   @   @   @
#
#
#
# @   @   @   @   @   @
#
#       .........
#       .       .
# @   @ . @   @ . @   @
#       .       .
#       .       .
#       .       .
# @   @ . @   @ . @   @
#       .       .
#       .........
#
# @   @   @   @   @   @
#
#
#
# @   @   @   @   @   @

# %%
import tensorflow as tf

from base import ml

# %%
# Set to False to use existing weights for the neural network.
# Set to True to continue training the weights from where we left off last time.
TRAIN = True

# %%
### DNN hyperparameters
for width in (64, 128, 256, 512):
    for depth in (2, 4, 6, 8, 10):
        hidden_units = [width] * depth
        logits = 1
        processor = ml.ScaleCenterAtPoint()
        activation=tf.nn.crelu

        ### Training hyperparameters #1
        drop_rate = 0.0
        drop_type = 'dropout'
        gradient_clip = 1.0  # May be set to None to turn off gradient clipping

        ### Logging/saving hyperparameters
        log_steps = 1000  # How many steps to print the current loss.
        model_dir_base = './saved_models/point/'
        uuid = None
        model_dir = ml.model_dir_str(model_dir_base, hidden_units, logits,
                                     processor=processor, activation=activation, 
                                     uuid=uuid)

        compile_kwargs = {'gradient_clip': gradient_clip,
                          'processor': processor,
                          'model_dir': model_dir}
        dnn_factory = ml.DNNFactory(hidden_units, logits, drop_rate=drop_rate,
                                    drop_type=drop_type, log_steps=log_steps, 
                                    activation=activation, batch_norm=False,
                                    compile_kwargs=compile_kwargs)

        max_steps = 0
        if TRAIN:
            gen_one_data = ml.GenSolutionPoint(fenics_from_save=True)

            ### Training hyperparameters #2
            batch_size = 32
            max_steps += 5000
            learning_rate = 0.001
            with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
                dnn = dnn_factory(learning_rate=learning_rate)
                dnn.train(input_fn=train_input_fn, max_steps=max_steps)

            batch_size = 128
            max_steps += 5000
            learning_rate = 0.001
            with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
                dnn = dnn_factory(learning_rate=learning_rate)
                dnn.train(input_fn=train_input_fn, max_steps=max_steps)

            batch_size = 256
            max_steps += 3000
            learning_rate = 0.0001
            with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
                dnn = dnn_factory(learning_rate=learning_rate)
                dnn.train(input_fn=train_input_fn, max_steps=max_steps)

            batch_size = 512
            max_steps += 2000
            learning_rate = 0.00001
            with ml.BatchData.context(gen_one_data=gen_one_data, batch_size=batch_size) as train_input_fn:
                dnn = dnn_factory(learning_rate=learning_rate)
                dnn.train(input_fn=train_input_fn, max_steps=max_steps)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7599150710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.75195265, step = 1
# INFO:tensorflow:global_step/sec: 60.5688
# INFO:tensorflow:loss = 0.0622496, step = 1001 (16.512 sec)
# INFO:tensorflow:global_step/sec: 59.6336
# INFO:tensorflow:loss = 0.10644801, step = 2001 (16.770 sec)
# INFO:tensorflow:global_step/sec: 59.4441
# INFO:tensorflow:loss = 0.016690938, step = 3001 (16.822 sec)
# INFO:tensorflow:global_step/sec: 60.157
# INFO:tensorflow:loss = 0.027179753, step = 4001 (16.623 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.056762375.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7594099dd8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.054726608, step = 5001
# INFO:tensorflow:global_step/sec: 13.8754
# INFO:tensorflow:loss = 0.031529076, step = 6001 (72.072 sec)
# INFO:tensorflow:global_step/sec: 13.8511
# INFO:tensorflow:loss = 0.017103761, step = 7001 (72.196 sec)
# INFO:tensorflow:global_step/sec: 13.7212
# INFO:tensorflow:loss = 0.02186519, step = 8001 (72.880 sec)
# INFO:tensorflow:global_step/sec: 13.8542
# INFO:tensorflow:loss = 0.012755606, step = 9001 (72.181 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.015564528.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596cd2b38>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.012209667, step = 10001
# INFO:tensorflow:global_step/sec: 6.56311
# INFO:tensorflow:loss = 0.0059141912, step = 11001 (152.369 sec)
# INFO:tensorflow:global_step/sec: 6.57432
# INFO:tensorflow:loss = 0.036410373, step = 12001 (152.106 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.017510174.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596c9e400>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.006123974, step = 13001
# INFO:tensorflow:global_step/sec: 3.07524
# INFO:tensorflow:loss = 0.010697847, step = 14001 (325.180 sec)
# INFO:tensorflow:Saving checkpoints for 14819 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/517/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/530/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/64x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0047915746.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75566e7470>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.9347839, step = 1
# INFO:tensorflow:global_step/sec: 50.6601
# INFO:tensorflow:loss = 0.06782167, step = 1001 (19.742 sec)
# INFO:tensorflow:global_step/sec: 50.9806
# INFO:tensorflow:loss = 0.075752825, step = 2001 (19.614 sec)
# INFO:tensorflow:global_step/sec: 50.9031
# INFO:tensorflow:loss = 0.07197808, step = 3001 (19.645 sec)
# INFO:tensorflow:global_step/sec: 50.3729
# INFO:tensorflow:loss = 0.011952376, step = 4001 (19.852 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.09504092.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c8961f60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.027236514, step = 5001
# INFO:tensorflow:global_step/sec: 12.494
# INFO:tensorflow:loss = 0.026152762, step = 6001 (80.040 sec)
# INFO:tensorflow:global_step/sec: 12.2623
# INFO:tensorflow:loss = 0.02666597, step = 7001 (81.552 sec)
# INFO:tensorflow:global_step/sec: 12.8688
# INFO:tensorflow:loss = 0.0189707, step = 8001 (77.706 sec)
# INFO:tensorflow:global_step/sec: 13.2434
# INFO:tensorflow:loss = 0.011764706, step = 9001 (75.510 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.046058603.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75566fc320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.026325978, step = 10001
# INFO:tensorflow:global_step/sec: 6.32186
# INFO:tensorflow:loss = 0.0060478165, step = 11001 (158.183 sec)
# INFO:tensorflow:global_step/sec: 6.30784
# INFO:tensorflow:loss = 0.005985369, step = 12001 (158.533 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.006350434.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c8740f60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0049443725, step = 13001
# INFO:tensorflow:global_step/sec: 3.00481
# INFO:tensorflow:loss = 0.0059707314, step = 14001 (332.801 sec)
# INFO:tensorflow:Saving checkpoints for 14803 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/517/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/530/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/64x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0041473983.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596a57e48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.6678632, step = 1
# INFO:tensorflow:global_step/sec: 51.9528
# INFO:tensorflow:loss = 0.03545652, step = 1001 (19.251 sec)
# INFO:tensorflow:global_step/sec: 52.4017
# INFO:tensorflow:loss = 0.4798862, step = 2001 (19.086 sec)
# INFO:tensorflow:global_step/sec: 52.3318
# INFO:tensorflow:loss = 0.21589424, step = 3001 (19.106 sec)
# INFO:tensorflow:global_step/sec: 52.2753
# INFO:tensorflow:loss = 0.052541547, step = 4001 (19.142 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.067611836.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c81712e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.06179624, step = 5001
# INFO:tensorflow:global_step/sec: 12.8924
# INFO:tensorflow:loss = 0.010616968, step = 6001 (77.568 sec)
# INFO:tensorflow:global_step/sec: 13.2286
# INFO:tensorflow:loss = 0.030017436, step = 7001 (75.593 sec)
# INFO:tensorflow:global_step/sec: 13.2312
# INFO:tensorflow:loss = 0.033037826, step = 8001 (75.579 sec)
# INFO:tensorflow:global_step/sec: 13.0684
# INFO:tensorflow:loss = 0.03344622, step = 9001 (76.520 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.015520318.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c9143ef0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.011374635, step = 10001
# INFO:tensorflow:global_step/sec: 6.16953
# INFO:tensorflow:loss = 0.00556813, step = 11001 (162.092 sec)
# INFO:tensorflow:global_step/sec: 6.09235
# INFO:tensorflow:loss = 0.012506349, step = 12001 (164.136 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.012263349.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c87d1ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.00857857, step = 13001
# INFO:tensorflow:global_step/sec: 2.91189
# INFO:tensorflow:loss = 0.0058919336, step = 14001 (343.421 sec)
# INFO:tensorflow:Saving checkpoints for 14747 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/517/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/530/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/64x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0053832103.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7599071ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.69920826, step = 1
# INFO:tensorflow:global_step/sec: 50.0578
# INFO:tensorflow:loss = 0.102850825, step = 1001 (19.979 sec)
# INFO:tensorflow:global_step/sec: 51.5058
# INFO:tensorflow:loss = 0.22013524, step = 2001 (19.416 sec)
# INFO:tensorflow:global_step/sec: 50.3381
# INFO:tensorflow:loss = 0.0106006805, step = 3001 (19.869 sec)
# INFO:tensorflow:global_step/sec: 49.8316
# INFO:tensorflow:loss = 0.031252213, step = 4001 (20.064 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.040792026.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c841dcc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.042610005, step = 5001
# INFO:tensorflow:global_step/sec: 12.7458
# INFO:tensorflow:loss = 0.017653968, step = 6001 (78.459 sec)
# INFO:tensorflow:global_step/sec: 12.8729
# INFO:tensorflow:loss = 0.022518259, step = 7001 (77.682 sec)
# INFO:tensorflow:global_step/sec: 12.7275
# INFO:tensorflow:loss = 0.025792003, step = 8001 (78.571 sec)
# INFO:tensorflow:global_step/sec: 12.9887
# INFO:tensorflow:loss = 0.0118465535, step = 9001 (77.000 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.013661563.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c89b0d30>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.019167818, step = 10001
# INFO:tensorflow:global_step/sec: 6.11725
# INFO:tensorflow:loss = 0.021489613, step = 11001 (163.475 sec)
# INFO:tensorflow:global_step/sec: 6.07101
# INFO:tensorflow:loss = 0.005902536, step = 12001 (164.717 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.019436847.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c850a400>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0066976883, step = 13001
# INFO:tensorflow:global_step/sec: 2.87888
# INFO:tensorflow:loss = 0.014425865, step = 14001 (347.360 sec)
# INFO:tensorflow:Saving checkpoints for 14733 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/517/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/532/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/531/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/528/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/535/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/529/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/530/tvals.npy'
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/534/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/64x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.004103821.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c878f240>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.38766462, step = 1
# INFO:tensorflow:global_step/sec: 48.5534
# INFO:tensorflow:loss = 0.06075514, step = 1001 (20.598 sec)
# INFO:tensorflow:global_step/sec: 49.4978
# INFO:tensorflow:loss = 0.081627965, step = 2001 (20.203 sec)
# INFO:tensorflow:global_step/sec: 48.9235
# INFO:tensorflow:loss = 0.04581582, step = 3001 (20.440 sec)
# INFO:tensorflow:global_step/sec: 50.08
# INFO:tensorflow:loss = 0.025439052, step = 4001 (19.971 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.026333712.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596d97518>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.053106792, step = 5001
# INFO:tensorflow:global_step/sec: 12.553
# INFO:tensorflow:loss = 0.019603755, step = 6001 (79.667 sec)
# INFO:tensorflow:global_step/sec: 12.6987
# INFO:tensorflow:loss = 0.030785773, step = 7001 (78.749 sec)
# INFO:tensorflow:global_step/sec: 12.4435
# INFO:tensorflow:loss = 0.020265687, step = 8001 (80.366 sec)
# INFO:tensorflow:global_step/sec: 12.4535
# INFO:tensorflow:loss = 0.0065631345, step = 9001 (80.293 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.038241304.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596b735c0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.01832466, step = 10001
# INFO:tensorflow:global_step/sec: 5.95627
# INFO:tensorflow:loss = 0.015515266, step = 11001 (167.893 sec)
# INFO:tensorflow:global_step/sec: 7.51117
# INFO:tensorflow:loss = 0.0058940407, step = 12001 (133.134 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.01397939.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c87cc588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.006164987, step = 13001
# INFO:tensorflow:global_step/sec: 4.27748
# INFO:tensorflow:loss = 0.0060779443, step = 14001 (233.785 sec)
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/525/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/64x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00709066.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c8901630>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 1.2168669, step = 1
# INFO:tensorflow:global_step/sec: 72.0676
# INFO:tensorflow:loss = 0.046940237, step = 1001 (13.878 sec)
# INFO:tensorflow:global_step/sec: 75.2268
# INFO:tensorflow:loss = 0.038256697, step = 2001 (13.293 sec)
# INFO:tensorflow:global_step/sec: 74.7476
# INFO:tensorflow:loss = 0.053973634, step = 3001 (13.378 sec)
# INFO:tensorflow:global_step/sec: 75.9927
# INFO:tensorflow:loss = 0.049979024, step = 4001 (13.159 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.28275248.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7596aa22e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.03518413, step = 5001
# INFO:tensorflow:global_step/sec: 18.6292
# INFO:tensorflow:loss = 0.041378137, step = 6001 (53.681 sec)
# INFO:tensorflow:global_step/sec: 18.825
# INFO:tensorflow:loss = 0.00909066, step = 7001 (53.120 sec)
# INFO:tensorflow:global_step/sec: 18.5687
# INFO:tensorflow:loss = 0.052070707, step = 8001 (53.854 sec)
# INFO:tensorflow:global_step/sec: 18.6596
# INFO:tensorflow:loss = 0.02940064, step = 9001 (53.592 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.014324432.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c8245f28>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.015886663, step = 10001
# INFO:tensorflow:global_step/sec: 9.06366
# INFO:tensorflow:loss = 0.0086985305, step = 11001 (110.332 sec)
# INFO:tensorflow:global_step/sec: 9.05727
# INFO:tensorflow:loss = 0.012972983, step = 12001 (110.408 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.006013779.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c9104ba8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0056955935, step = 13001
# INFO:tensorflow:global_step/sec: 4.468
# INFO:tensorflow:loss = 0.010968029, step = 14001 (223.816 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/128x2_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00560358.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c84a75c0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.97272164, step = 1
# INFO:tensorflow:global_step/sec: 67.4051
# INFO:tensorflow:loss = 0.65074533, step = 1001 (14.837 sec)
# INFO:tensorflow:global_step/sec: 68.4704
# INFO:tensorflow:loss = 0.14834535, step = 2001 (14.605 sec)
# INFO:tensorflow:global_step/sec: 68.6889
# INFO:tensorflow:loss = 0.036285937, step = 3001 (14.558 sec)
# INFO:tensorflow:global_step/sec: 68.2929
# INFO:tensorflow:loss = 0.024832297, step = 4001 (14.643 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.029441979.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75990e8860>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.017678764, step = 5001
# INFO:tensorflow:global_step/sec: 17.9255
# INFO:tensorflow:loss = 0.016938923, step = 6001 (55.788 sec)
# INFO:tensorflow:global_step/sec: 17.9198
# INFO:tensorflow:loss = 0.009272616, step = 7001 (55.804 sec)
# INFO:tensorflow:global_step/sec: 17.4911
# INFO:tensorflow:loss = 0.012825217, step = 8001 (57.172 sec)
# INFO:tensorflow:global_step/sec: 17.7318
# INFO:tensorflow:loss = 0.040452458, step = 9001 (56.395 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13248158.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75c826fda0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.020659806, step = 10001
# INFO:tensorflow:global_step/sec: 8.78543
# INFO:tensorflow:loss = 0.0069042277, step = 11001 (113.826 sec)
# INFO:tensorflow:global_step/sec: 8.6838
# INFO:tensorflow:loss = 0.050041176, step = 12001 (115.157 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/128x4_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0067176875.
# ...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x6_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/512x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0059770066, step = 13001
# INFO:tensorflow:global_step/sec: 2.36411
# INFO:tensorflow:loss = 0.00546315, step = 14001 (422.994 sec)
# INFO:tensorflow:Saving checkpoints for 14431 into ./saved_models/point_general/512x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/525/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/512x6_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0026028906.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75567c89e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 1.192647, step = 1
# INFO:tensorflow:global_step/sec: 19.705
# INFO:tensorflow:loss = 0.15969111, step = 1001 (50.750 sec)
# INFO:tensorflow:global_step/sec: 19.2062
# INFO:tensorflow:loss = 0.12701456, step = 2001 (52.067 sec)
# INFO:tensorflow:global_step/sec: 19.7189
# INFO:tensorflow:loss = 0.08173098, step = 3001 (50.713 sec)
# INFO:tensorflow:global_step/sec: 19.7063
# INFO:tensorflow:loss = 0.3304093, step = 4001 (50.745 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14898008.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f754d6411d0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.072238654, step = 5001
# INFO:tensorflow:global_step/sec: 7.61626
# INFO:tensorflow:loss = 0.07932079, step = 6001 (131.300 sec)
# INFO:tensorflow:global_step/sec: 7.67835
# INFO:tensorflow:loss = 0.18779562, step = 7001 (130.236 sec)
# INFO:tensorflow:global_step/sec: 7.67146
# INFO:tensorflow:loss = 0.42360997, step = 8001 (130.354 sec)
# INFO:tensorflow:global_step/sec: 7.61768
# INFO:tensorflow:loss = 0.19463553, step = 9001 (131.273 sec)
# INFO:tensorflow:Saving checkpoints for 9590 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.058695022.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7556e8c4a8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.119515814, step = 10001
# INFO:tensorflow:global_step/sec: 4.1535
# INFO:tensorflow:loss = 0.0151811, step = 11001 (240.763 sec)
# INFO:tensorflow:global_step/sec: 4.14424
# INFO:tensorflow:loss = 0.0060793604, step = 12001 (241.298 sec)
# INFO:tensorflow:Saving checkpoints for 12487 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0074191876.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7556ecfcc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.009632889, step = 13001
# INFO:tensorflow:global_step/sec: 2.15936
# INFO:tensorflow:loss = 0.007591667, step = 14001 (463.103 sec)
# INFO:tensorflow:Saving checkpoints for 14296 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/525/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/512x8_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.005903746.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7556eafd68>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 3.8075964, step = 1
# INFO:tensorflow:global_step/sec: 16.7912
# INFO:tensorflow:loss = 4.5741982, step = 1001 (59.557 sec)
# INFO:tensorflow:global_step/sec: 16.9611
# INFO:tensorflow:loss = 1.42589, step = 2001 (58.959 sec)
# INFO:tensorflow:global_step/sec: 16.9593
# INFO:tensorflow:loss = 0.48158878, step = 3001 (58.965 sec)
# INFO:tensorflow:global_step/sec: 16.9659
# INFO:tensorflow:loss = 0.6506336, step = 4001 (58.941 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.7765282.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7556f92e48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.3914262, step = 5001
# INFO:tensorflow:global_step/sec: 6.777
# INFO:tensorflow:loss = 0.21733673, step = 6001 (147.560 sec)
# INFO:tensorflow:global_step/sec: 6.74192
# INFO:tensorflow:loss = 0.13940716, step = 7001 (148.326 sec)
# INFO:tensorflow:global_step/sec: 6.73428
# INFO:tensorflow:loss = 0.1375178, step = 8001 (148.494 sec)
# INFO:tensorflow:global_step/sec: 6.70888
# INFO:tensorflow:loss = 0.03279075, step = 9001 (149.056 sec)
# INFO:tensorflow:Saving checkpoints for 9042 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.30801785.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75940caf98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.10667746, step = 10001
# INFO:tensorflow:global_step/sec: 3.62506
# INFO:tensorflow:loss = 0.01504514, step = 11001 (275.859 sec)
# INFO:tensorflow:global_step/sec: 3.62298
# INFO:tensorflow:loss = 0.008662073, step = 12001 (276.016 sec)
# INFO:tensorflow:Saving checkpoints for 12175 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0117634.
# INFO:tensorflow:Using config: {'_model_dir': './saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75990c96a0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:loss = 0.0075182975, step = 13001
# INFO:tensorflow:Saving checkpoints for 13854 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.47368
# INFO:tensorflow:loss = 0.005675654, step = 14001 (678.577 sec)
# INFO:tensorflow:Error whilst loading FEnicCS solution from save; generating FEniCS solution instead. Error message: [Errno 2] No such file or directory: './fenics_data/525/tvals.npy'
# INFO:tensorflow:Saving checkpoints for 14998 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 15000 into ./saved_models/point_general/512x10_1__ScaleCenterAtPoint_crelu/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0057118754.
